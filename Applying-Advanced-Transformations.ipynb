# %%
import pandas as pd
import json
import seaborn as sns

# %%
df_power = pd.read_csv('C:/Users/Dell/Downloads/superhero_powers - superhero_powers.csv')
df_info = pd.read_csv('C:/Users/Dell/Downloads/superhero_info - superhero_info.csv')

# %%
df_power.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
df_info.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
df_info.columns
# Out:
# Index(['Hero|Publisher', 'Gender', 'Race', 'Alignment', 'Hair color',
#        'Eye color', 'Skin color', 'Measurements'],
#       dtype='object')

# %% [markdown]
# Cleaning superHero Info

# %%
df_info[['Hero', 'Publisher']]=df_info['Hero|Publisher'].str.split('|', expand = True)

# %%
df_info.head(5)
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# ...

# %%
df_info= df_info.drop(columns=['Hero|Publisher'])
df_info.head(5)
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %%
df_info.loc[0, 'Measurements']
# Out:
# "{'Height': '203.0 cm', 'Weight': '441.0 kg'}"

# %%
df_info['Measurements'] = df_info['Measurements'].str.replace("'", '"')

# %%
df_info['Measurements'] = df_info['Measurements'].apply(json.loads)
df_info.loc[0, 'Measurements']
# Out:
# {'Height': '203.0 cm', 'Weight': '441.0 kg'}

# %%
height_weight = df_info['Measurements'].apply(pd.Series)
height_weight
# Out:
#        Height    Weight
# 0    203.0 cm  441.0 kg
# 1    191.0 cm   65.0 kg
# 2    185.0 cm   90.0 kg
# 3    203.0 cm  441.0 kg
# 4    193.0 cm  122.0 kg
# ..        ...       ...
# 458  183.0 cm   83.0 kg
# 459  165.0 cm   52.0 kg
# 460   66.0 cm   17.0 kg
# 461  170.0 cm   57.0 kg
# 462  185.0 cm   81.0 kg
#
# [463 rows x 2 columns]

# %%
df_info = pd.concat((df_info, height_weight), axis = 1)
df_info.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
#
#                                    Measurements        Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg

# %%
df_info = df_info.drop(columns=['Measurements'])
df_info.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color        Hero  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg

# %%
df_info['Height'] = df_info['Height'].str.replace(' cm', '')
df_info['Height'].head(2)
# Out:
# 0    203.0
# 1    191.0
# Name: Height, dtype: object

# %%
df_info['Height'] = pd.to_numeric(df_info['Height'])

# %%
df_info['Weight'] = df_info['Weight'].str.replace(' kg', '')
df_info['Weight'].head(2)
# Out:
# 0    441.0
# 1     65.0
# Name: Weight, dtype: object

# %%
df_info['Weight'] = pd.to_numeric(df_info['Weight'])

# %% [markdown]
# Cleaning superHero Info

# %%
df_power['Powers'].head(2)
# Out:
# 0           Agility,Super Strength,Stamina,Super Speed
# 1    Accelerated Healing,Durability,Longevity,Super...
# Name: Powers, dtype: object

# %%
df_power.loc[0, 'Powers']
# Out:
# 'Agility,Super Strength,Stamina,Super Speed'

# %%
df_power['powers_split'] = df_power['Powers'].str.split(',')
df_power['powers_split'].head()
# Out:
# 0      [Agility, Super Strength, Stamina, Super Speed]
# 1    [Accelerated Healing, Durability, Longevity, S...
# 2    [Agility, Accelerated Healing, Cold Resistance...
# 3                                 [Lantern Power Ring]
# 4    [Accelerated Healing, Intelligence, Super Stre...
# Name: powers_split, dtype: object

# %%
exploded = df_power.explode('powers_split')
exploded.head()
# Out:
#   hero_names                                             Powers  \
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1     A-Bomb  Accelerated Healing,Durability,Longevity,Super...
#
#           powers_split
# 0              Agility
# 0       Super Strength
# 0              Stamina
# 0          Super Speed
# 1  Accelerated Healing

# %%
cols_to_make = exploded['powers_split'].dropna().unique()

# %%
for col in cols_to_make:
    df_power[col] = df_power['Powers'].str.contains(col).copy() 
df_power.head()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7948\364298710.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_power[col] = df_power['Powers'].str.contains(col).copy()
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7948\364298710.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_power[col] = df_power['Powers'].str.contains(col).copy()
# ...

# %%
df = pd.merge (df_info, df_power, left_on = 'Hero', right_on = 'hero_names')
df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher  Height  Weight  ... Weather Control  \
# 0         A-Bomb      Marvel Comics   203.0   441.0  ...           False
# 1     Abe Sapien  Dark Horse Comics   191.0    65.0  ...           False
# 2       Abin Sur          DC Comics   185.0    90.0  ...           False
# 3    Abomination      Marvel Comics   203.0   441.0  ...           False
# 4  Absorbing Man      Marvel Comics   193.0   122.0  ...           False
#
#   Omnipresent Omniscient  Hair Manipulation  Nova Force  Odin Force  \
# ...

# %% [markdown]
# Compare the average weight of super powers who have Super Speed to those who do not.

# %%
df.groupby('Super Speed')['Weight'].mean()
# Out:
# Super Speed
# False    101.773585
# True     129.404040
# Name: Weight, dtype: float64

# %%
sns.barplot(data=df, x='Super Speed',y='Weight')
# Out:
# <Axes: xlabel='Super Speed', ylabel='Weight'>

# %% [markdown]
# What is the average height of heroes for each publisher?

# %%
df.groupby('Publisher')['Height'].mean()
# Out:
# Publisher
# DC Comics            181.923913
# Dark Horse Comics    176.909091
# George Lucas         159.600000
# Image Comics         211.000000
# Marvel Comics        191.546128
# Shueisha             171.500000
# Star Trek            181.500000
# Team Epic TV         180.750000
# Unknown              178.000000
# Name: Height, dtype: float64

# %%
ax = sns.barplot(data=df, x='Publisher',y='Height')
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Marvel Comics'),
#  Text(1, 0, 'Dark Horse Comics'),
#  Text(2, 0, 'DC Comics'),
#  Text(3, 0, 'Team Epic TV'),
#  Text(4, 0, 'George Lucas'),
#  Text(5, 0, 'Shueisha'),
#  Text(6, 0, 'Star Trek'),
#  Text(7, 0, 'Unknown'),
#  Text(8, 0, 'Image Comics')]
